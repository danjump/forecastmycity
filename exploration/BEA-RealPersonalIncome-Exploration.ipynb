# %%
import pandas as pd
import numpy as np

# %%
print("Exploring Real person income:\n")

rpi_filename="/home/danielj/insight/project/data/BEA-RealPersonalIncome/RPI_MSA_2008_2013_nofooter.csv"

rpi_df = pd.read_csv(rpi_filename)

print rpi_df.head(5)

print("printing column names:\n")

column_names = rpi_df.columns.values.tolist()
print(column_names)

msa_df = rpi_df['IndustryClassification'].unique()

print("Number of unique Metropolitian Statistical Areas: %d\n"%len(msa_df))

print msa_df

rpi_totals_df = rpi_df[rpi_df['IndustryClassification']=='All industry total']
totals_values_df = rpi_totals_df[rpi_totals_df.columns[7:12]].astype(float)

is_nan_array = totals_values_df.isnull().sum()
print(is_nan_array)

#values_are_finite = rgdp_df[]
# Out:
# Exploring Real person income:
#
#    GeoFIPS                                      GeoName  Region Table  \
# 0        0                                United States     NaN  RPI1
# 1        0                                United States     NaN  RPI1
# 2      999      United States (Nonmetropolitan Portion)     NaN  RPI1
# 3      999      United States (Nonmetropolitan Portion)     NaN  RPI1
# 4    10180  Abilene, TX (Metropolitan Statistical Area)     NaN  RPI1
#
#    LineCode IndustryClassification  \
# 0         1                    ...
# 1         2                    ...
# 2         1                    ...
# 3         2                    ...
# 4         1                    ...
#
#                                          Description         2008  \
# 0  Real personal income (thousands of chained (20...  12421207863
# 1  Real per capita personal income (chained (2009...        40847
# 2  Real personal income (thousands of chained (20...   1700213985
# ...

# %%
test1='test1'
print test1+'test2'
# Out:
# test1test2

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
fig = plt.figure(figsize = (9,7))
ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.85)
ax.set_title('All Metropolitan Areas', fontsize=20)

ax.set_xlabel('Year', fontsize=20)
ax.set_ylabel('Real GDP', fontsize=20)

print totals_values_df.iloc[1]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-55115e63e420> in <module>()
#       7 ax.set_ylabel('Real GDP', fontsize=20)
#       8
# ----> 9 print totals_values_df.iloc[1]
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexing.pyc in __getitem__(self, key)
#    1187             return self._getitem_tuple(key)
#    1188         else:
# -> 1189             return self._getitem_axis(key, axis=0)
#    1190
#    1191     def _getitem_axis(self, key, axis=0):
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexing.pyc in _getitem_axis(self, key, axis)
#    1476
#    1477                 # validate the location
# -> 1478                 self._is_valid_integer(key, axis)
#    1479
#    1480             return self._get_loc(key, axis=axis)
#
# /usr/local/lib/python2.7/dist-packages/pandas/core/indexing.pyc in _is_valid_integer(self, key, axis)
# ...

# %%
fig = plt.figure(figsize = (9,7))
ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.85)
ax.set_title('Individual Metropolitan Areas', fontsize=20)

ax.set_xlabel('Year', fontsize=20)
ax.set_ylabel('Real GDP', fontsize=20)
for i in range(1,len(totals_values_df)):
    totals_values_df.iloc[i].plot()

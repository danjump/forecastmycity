# %%
import pandas as pd

# %%
sic_filename = '../../data/cleaned_data/regional_income_details_69-00.csv'
naics_filename = '../../data/cleaned_data/regional_income_details_01-13.csv'

s_df = pd.read_csv(sic_filename)
s_df.drop('Unnamed: 0', axis=1, inplace=True)

n_df = pd.read_csv(naics_filename)
n_df.drop('Unnamed: 0', axis=1, inplace=True)

# %%
print len(s_df)
s_df.head(1)
# Out:
# 43053
#    line_id              line_desc  GeoFips  \
# 0       10  [CA5] Personal income    10180
#
#                                        GeoName               CL_UNIT  \
# 0  Abilene, TX (Metropolitan Statistical Area)  thousands of dollars
#
#    UNIT_MULT    1969    1970    1971    1972   ...        1991     1992  \
# 0          3  395971  443561  474234  539294   ...     2376433  2538036
#
#       1993     1994     1995     1996     1997     1998     1999     2000
# 0  2663665  2722081  2918059  3109606  3329032  3490073  3639311  3741391
#
# [1 rows x 38 columns]

# %%
print len(n_df)
n_df.head(1)
# Out:
# 49911
#    line_id               line_desc  GeoFips  \
# 0       10  [CA5N] Personal income    10180
#
#                                        GeoName               CL_UNIT  \
# 0  Abilene, TX (Metropolitan Statistical Area)  thousands of dollars
#
#    UNIT_MULT     2001     2002     2003     2004     2005     2006     2007  \
# 0          3  3826121  3957936  4181505  4363728  4588171  4863397  5211004
#
#       2008     2009     2010     2011     2012     2013
# 0  5811434  5465772  5685546  6111898  6546641  6743442

# %%
ab_s_df = s_df[s_df['GeoFips']==10180]
print len(ab_s_df)
ab_s_df
# Out:
# 113
#        line_id                                          line_desc  GeoFips  \
# 0           10                              [CA5] Personal income    10180
# 381         20                         [CA5] Population (persons)    10180
# 762         30         [CA5] Per capita personal income (dollars)    10180
# 1143        35                    [CA5] Earnings by place of work    10180
# 1524        36  [CA5] less: Contributions for government socia...    10180
# 1905        37  [CA5] Employee and self-employed contributions...    10180
# 2286        38  [CA5] Employer contributions for government so...    10180
# 2667        42               [CA5] plus: Adjustment for residence    10180
# 3048        45   [CA5] equals: Net earnings by place of residence    10180
# 3429        46          [CA5] plus: Dividends, interest, and rent    10180
# 3810        47     [CA5] plus: Personal current transfer receipts    10180
# ...

# %%
ab_n_df = n_df[n_df['GeoFips']==10180]
print len(ab_n_df)
ab_n_df
# Out:
# 131
#        line_id                                          line_desc  GeoFips  \
# 0           10                             [CA5N] Personal income    10180
# 381         20                        [CA5N] Population (persons)    10180
# 762         30        [CA5N] Per capita personal income (dollars)    10180
# 1143        35                   [CA5N] Earnings by place of work    10180
# 1524        36  [CA5N] less: Contributions for government soci...    10180
# 1905        37  [CA5N] Employee and self-employed contribution...    10180
# 2286        38  [CA5N] Employer contributions for government s...    10180
# 2667        42              [CA5N] plus: Adjustment for residence    10180
# 3048        45  [CA5N] equals: Net earnings by place of residence    10180
# 3429        46         [CA5N] plus: Dividends, interest, and rent    10180
# 3810        47    [CA5N] plus: Personal current transfer receipts    10180
# ...

# %%
ab_s_df[ab_s_df['line_id']==100]
# Out:
#       line_id                                          line_desc  GeoFips  \
# 8001      100  [CA5] Agricultural services, forestry, and fis...    10180
#
#                                           GeoName               CL_UNIT  \
# 8001  Abilene, TX (Metropolitan Statistical Area)  thousands of dollars
#
#       UNIT_MULT  1969  1970  1971  1972  ...    1991   1992   1993   1994  \
# 8001          3  3442  3087  3361  4088  ...    9598  10227  10954  13030
#
#        1995   1996   1997   1998   1999   2000
# 8001  12413  13870  21720  23236  29284  24990
#
# [1 rows x 38 columns]

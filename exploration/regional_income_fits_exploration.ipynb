# %%
import pandas as pd

# %%
infile = 

df1 = pd.read_csv(infile1)
df2 = pd.read_csv(infile2)
# Out:
# /usr/local/lib/python2.7/dist-packages/pandas/io/parsers.py:1170: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   data = self._reader.read(nrows)

# %%
print df1.head(1)
print df1.columns
df1_red = df1[['line_id','line_desc','DataValue','GeoFips','GeoName','TimePeriod','CL_UNIT','UNIT_MULT']]
print df1_red.columns
# Out:
#    Unnamed: 0               CL_UNIT    Code DataValue  GeoFips  \
# 0           0  thousands of dollars  CA5-10    443561    10180
#
#                                        GeoName NoteRef  TimePeriod  UNIT_MULT  \
# 0  Abilene, TX (Metropolitan Statistical Area)     NaN        1970          3
#
#    line_id              line_desc
# 0       10  [CA5] Personal income
# Index([u'Unnamed: 0', u'CL_UNIT', u'Code', u'DataValue', u'GeoFips',
#        u'GeoName', u'NoteRef', u'TimePeriod', u'UNIT_MULT', u'line_id',
#        u'line_desc'],
#       dtype='object')
# Index([u'line_id', u'line_desc', u'DataValue', u'GeoFips', u'GeoName',
#        u'TimePeriod', u'CL_UNIT', u'UNIT_MULT'],
#       dtype='object')

# %%
df1_reindex = df1_red.set_index(['line_id','line_desc','GeoFips','GeoName','CL_UNIT','UNIT_MULT','TimePeriod'])

print len(df1_reindex)
print df1_reindex.head(10)
print '---------------------'

df1_unstack = df1_reindex.unstack()
print df1_unstack.head(10)
print '---------------------'

df1_unstack.columns = df1_unstack.columns.get_level_values(1).values
print df1_unstack.head(10)
print '---------------------'

df1_unstack = df1_unstack.reset_index()

df1_unstack.head(5)
# Out:
# 1377696
#                                                                                                                             DataValue
# line_id line_desc             GeoFips GeoName                                     CL_UNIT              UNIT_MULT TimePeriod
# 10      [CA5] Personal income 10180   Abilene, TX (Metropolitan Statistical Area) thousands of dollars 3         1970          443561
#                                                                                                                  1997         3329032
#                                                                                                                  1998         3490073
#                                                                                                                  1974          653309
#                                                                                                                  1975          767316
# ...

# %%
df1_unstack.to_csv('test.txt')

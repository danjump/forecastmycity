# %%
print [ex for ex in range(1, 3), 1]
# Out:
# [[1, 2], 1]

# %%
c_set = []
for ex in range(-50,50):
    for fac in range(1,10):
        c_set.append(fac*(2**ex))
        
print c_set
# Out:
# [8.881784197001252e-16, 1.7763568394002505e-15, 2.6645352591003757e-15, 3.552713678800501e-15, 4.440892098500626e-15, 5.329070518200751e-15, 6.217248937900877e-15, 7.105427357601002e-15, 7.993605777301127e-15, 1.7763568394002505e-15, 3.552713678800501e-15, 5.329070518200751e-15, 7.105427357601002e-15, 8.881784197001252e-15, 1.0658141036401503e-14, 1.2434497875801753e-14, 1.4210854715202004e-14, 1.5987211554602254e-14, 3.552713678800501e-15, 7.105427357601002e-15, 1.0658141036401503e-14, 1.4210854715202004e-14, 1.7763568394002505e-14, 2.1316282072803006e-14, 2.4868995751603507e-14, 2.842170943040401e-14, 3.197442310920451e-14, 7.105427357601002e-15, 1.4210854715202004e-14, 2.1316282072803006e-14, 2.842170943040401e-14, 3.552713678800501e-14, 4.263256414560601e-14, 4.973799150320701e-14, 5.684341886080802e-14, 6.394884621840902e-14, 1.4210854715202004e-14, 2.842170943040401e-14, 4.263256414560601e-14, 5.684341886080802e-14, 7.105427357601002e-14, 8.526512829121202e-14, 9.94759830064140
# ...

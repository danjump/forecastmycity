# %%
import pandas as pd
import numpy as np
import datetime

# %%
start_time = datetime.datetime.now()

df = pd.read_csv("/home/danielj/insight/project/data/yelp_dataset_challenge_academic_dataset/yelp_reviews_sentiment.csv")

end_time = datetime.datetime.now()
delta = end_time - start_time
sec = delta.total_seconds() # seconds
print 'Total loop duration(s) = %.3f'%sec
# Out:
# Total loop duration(s) = 2.892

# %%
print len(df)
print df.head(5)
print df.tail(5)
# Out:
# 1569264
#    Unnamed: 0             business_id        date  stars  \
# 0           0  jtzhY-P4H6WSYpv5rWhxtw  2014-08-28      5
# 1           1  jtzhY-P4H6WSYpv5rWhxtw  2014-09-05      2
# 2           2  jtzhY-P4H6WSYpv5rWhxtw  2014-09-07      3
# 3           3  jtzhY-P4H6WSYpv5rWhxtw  2014-09-09      5
# 4           4  jtzhY-P4H6WSYpv5rWhxtw  2014-09-24      5
#
#                                      votes  polarity  subjectivity
# 0  {u'funny': 0, u'useful': 0, u'cool': 0}  0.488205      0.832479
# 1  {u'funny': 1, u'useful': 4, u'cool': 0} -0.073214      0.523036
# 2  {u'funny': 0, u'useful': 0, u'cool': 0}  0.328855      0.597912
# 3  {u'funny': 0, u'useful': 0, u'cool': 0}  0.290330      0.593736
# 4  {u'funny': 0, u'useful': 1, u'cool': 0}  0.431250      0.562500
#          Unnamed: 0             business_id        date  stars  \
# 1569259     1569259  jBb5KHHAj4s8hcXVS6QXDg  2009-06-19      4
# 1569260     1569260  jBb5KHHAj4s8hcXVS6QXDg  2009-06-21      3
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.figure()

df[['stars','polarity','subjectivity']].hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f05e1365d50>,
# ...
#         <matplotlib.axes._subplots.AxesSubplot object at 0x7f05e11eedd0>]], dtype=object)

# %%
fig = plt.figure(figsize = (9,7))
ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.85)
#ax.set_title('axes title')

ax.set_xlabel('Rating (Stars)', fontsize=20)
ax.set_ylabel('Review Sentiment: Polarity', fontsize=20)

hist = plt.hist2d(df['stars'], df['polarity'], bins=[5,50])

# %%
fig = plt.figure(figsize = (9,7))
ax = fig.add_subplot(111)
fig.subplots_adjust(top=0.85)
#ax.set_title('axes title')

ax.set_xlabel('Rating (Stars)', fontsize=20)
ax.set_ylabel('Review Sentiment: Subjectivity', fontsize=20)

hist = plt.hist2d(df['stars'], df['subjectivity'], bins=[5,50])
